# %% [markdown]
# - Testing and monitoring are two different things.
# - Testing is done during development or before deployment.

# %%
def add(a: int, b: int) -> int:
    return a / b

# %%
# assert
assert 1 + 1 == 2

# %%
assert 1 + 1 == 3

# %%
def test_add():
    assert add(1, 2) == 3
    assert add(-1, 1) == 0
    assert add(0, 0) == 0
    assert add(-1, -1) == -2


test_add()
