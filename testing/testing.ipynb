# %% [markdown]
# - Testing and monitoring are two different things.
# - Testing is done during development or before deployment.

# %%
def add(a: int, b: int) -> int:
    return a / b

# %%
# assert
assert 1 + 1 == 2

# %%
assert 1 + 1 == 3
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 assert 1 + 1 == 3
#
# AssertionError:

# %%
def test_add():
    assert add(1, 2) == 3
    assert add(-1, 1) == 0
    assert add(0, 0) == 0
    assert add(-1, -1) == -2


test_add()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 8
#       4     assert add(0, 0) == 0
#       5     assert add(-1, -1) == -2
# ----> 8 test_add()
#
# Cell In[6], line 2, in test_add()
#       1 def test_add():
# ----> 2     assert add(1, 2) == 3
#       3     assert add(-1, 1) == 0
#       4     assert add(0, 0) == 0
#
# AssertionError:
